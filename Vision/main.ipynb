# %%
# # !pip install GitPython
# from git import Repo

# repo_url = 'https://github.com/IDKiro/DehazeFormer'

# # Directory where you want to clone the repository
# clone_directory = './'

# Repo.clone_from(repo_url, clone_directory)

# Optionally, you can pull the latest changes
# repo = Repo(clone_directory)
# repo.remotes.origin.pull()


import shutil
import os

# Path to the directory containing the .git folder
directory_path = './'

# Delete the .git folder
git_folder_path = os.path.join(directory_path, '.git')
shutil.rmtree(git_folder_path)

print(".git folder deleted successfully.")
# Out:
# ---------------------------------------------------------------------------
# InvalidGitRepositoryError                 Traceback (most recent call last)
# Cell In[8], line 12
#       7 clone_directory = './'
#       9 # Repo.clone_from(repo_url, clone_directory)
#      10
#      11 # Optionally, you can pull the latest changes
# ---> 12 repo = Repo(clone_directory)
#      13 repo.remotes.origin.pull()
#      16 import shutil
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\git\repo\base.py:276, in Repo.__init__(self, path, odbt, search_parent_directories, expand_vars)
#     273 # END while curpath
#     275 if git_dir is None:
# --> 276     raise InvalidGitRepositoryError(epath)
#     277 self.git_dir = git_dir
#     279 self._bare = False
#
# InvalidGitRepositoryError: c:\Users\Hp\OneDrive - Higher Education Commission\Desktop\Year3\DL\Project\Vision Transformer\Vision-Transformer-Image-Dehazing\Vision

# %%
import os
import shutil
import random

# Define paths
data_dir = "data/NH-HAZE"
train_dir = "data/NH-HAZE/train"
test_dir = "data/NH-HAZE/test"

# Create train and test directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Create GT and hazy subdirectories inside train and test directories
for directory in [train_dir, test_dir]:
    os.makedirs(os.path.join(directory, "GT"), exist_ok=True)
    os.makedirs(os.path.join(directory, "hazy"), exist_ok=True)

# Move images into GT and hazy subdirectories
for i in range(1, 56):
    gt_filename = f"{i:02d}_GT.png"
    hazy_filename = f"{i:02d}_hazy.png"
    
    # Determine whether the image should be in train or test set
    if random.random() < 0.8:  # 80% train, 20% test
        dest_dir = train_dir
    else:
        dest_dir = test_dir

    # Move GT image
    shutil.move(os.path.join(data_dir, gt_filename), os.path.join(dest_dir, "GT", gt_filename))
    # Move hazy image
    shutil.move(os.path.join(data_dir, hazy_filename), os.path.join(dest_dir, "hazy", hazy_filename))

# %%
#File renaming since NH-HAZE has files name 001_GT.png and 001_hazy.png

import os

def rename_files(directory):
    for filename in os.listdir(directory):
        if "GT" in filename:
            new_filename = filename.replace("GT", "")
            old_path = os.path.join(directory, filename)
            new_path = os.path.join(directory, new_filename)
            os.rename(old_path, new_path)
            print(f"Renamed {filename} to {new_filename}")

def rename_files2(directory):
    for filename in os.listdir(directory):
        if "hazy" in filename:
            new_filename = filename.replace("hazy", "")
            old_path = os.path.join(directory, filename)
            new_path = os.path.join(directory, new_filename)
            os.rename(old_path, new_path)
            print(f"Renamed {filename} to {new_filename}")
# Replace 'directory_path' with the path to your directory containing the files
directory_path = './data/NH-HAZE/test/GT'
directory_path2 = './data/NH-HAZE/test/hazy'
rename_files(directory_path)
rename_files2(directory_path2)
# Out:
# Renamed 03_hazy.png to 03_.png
# Renamed 19_hazy.png to 19_.png
# Renamed 20_hazy.png to 20_.png
# Renamed 23_hazy.png to 23_.png
# Renamed 26_hazy.png to 26_.png
# Renamed 27_hazy.png to 27_.png
# Renamed 28_hazy.png to 28_.png
# Renamed 31_hazy.png to 31_.png
# Renamed 48_hazy.png to 48_.png

# %%
#bedde paths
import os
import shutil
import random

# Path to the BeDDe dataset folder
bedde_folder = "BeDDe"

# Output folders
output_train_hazy = "data/Outdoor/train/hazy"
output_train_gt = "data/Outdoor/train/GT"
output_test_hazy = "data/Outdoor/test/hazy"
output_test_gt = "data/Outdoor/test/GT"

# Function to extract fog, gt pairs
def extract_pairs(bedde_folder):
    folders = os.listdir(bedde_folder)
    ind=0
    for folder_name in folders:
        fog_folder = os.path.join(bedde_folder, folder_name, "fog")
        gt_folder = os.path.join(bedde_folder, folder_name, "gt")
        
        fog_files = os.listdir(fog_folder)
        gt_file = os.listdir(gt_folder)[0]  # Assuming there's only one ground truth image
        
        for idx, fog_file in enumerate(fog_files):
            fog_path = os.path.join(fog_folder, fog_file)
            gt_path = os.path.join(gt_folder, gt_file)
            
            
            output_fog_name = f"{ind+1+55}_.png"
            output_gt_name = f"{ind+1+55}_.png"
            ind+=1
            
            yield fog_path, gt_path, output_fog_name, output_gt_name

# Extract fog, gt pairs
pairs = list(extract_pairs(bedde_folder))
print(f"Extracted {len(pairs)} fog, gt pairs")

for i in range(0, 20):
    print(pairs[i])
# Shuffle pairs
random.shuffle(pairs)

# Split into train and test
split_index = int(len(pairs) * 0.8)
train_pairs = pairs[:split_index]
test_pairs = pairs[split_index:]
# Out:
# Extracted 208 fog, gt pairs
# ('BeDDe\\beijing\\fog\\beijing_1.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '56_.png', '56_.png')
# ('BeDDe\\beijing\\fog\\beijing_10.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '57_.png', '57_.png')
# ('BeDDe\\beijing\\fog\\beijing_11.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '58_.png', '58_.png')
# ('BeDDe\\beijing\\fog\\beijing_12.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '59_.png', '59_.png')
# ('BeDDe\\beijing\\fog\\beijing_13.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '60_.png', '60_.png')
# ('BeDDe\\beijing\\fog\\beijing_14.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '61_.png', '61_.png')
# ('BeDDe\\beijing\\fog\\beijing_15.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '62_.png', '62_.png')
# ('BeDDe\\beijing\\fog\\beijing_2.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '63_.png', '63_.png')
# ('BeDDe\\beijing\\fog\\beijing_3.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '64_.png', '64_.png')
# ('BeDDe\\beijing\\fog\\beijing_4.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '65_.png', '65_.png')
# ('BeDDe\\beijing\\fog\\beijing_5.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '66_.png', '66_.png')
# ('BeDDe\\beijing\\fog\\beijing_6.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '67_.png', '67_.png')
# ('BeDDe\\beijing\\fog\\beijing_7.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '68_.png', '68_.png')
# ('BeDDe\\beijing\\fog\\beijing_8.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '69_.png', '69_.png')
# ('BeDDe\\beijing\\fog\\beijing_9.png', 'BeDDe\\beijing\\gt\\beijing_clear.png', '70_.png', '70_.png')
# ('BeDDe\\changsha\\fog\\changsha_1.png', 'BeDDe\\changsha\\gt\\changsha_clear.png', '71_.png', '71_.png')
# ('BeDDe\\changsha\\fog\\changsha_2.png', 'BeDDe\\changsha\\gt\\changsha_clear.png', '72_.png', '72_.png')
# ('BeDDe\\changsha\\fog\\changsha_3.png', 'BeDDe\\changsha\\gt\\changsha_clear.png', '73_.png', '73_.png')
# ('BeDDe\\changsha\\fog\\changsha_4.png', 'BeDDe\\changsha\\gt\\changsha_clear.png', '74_.png', '74_.png')
# ('BeDDe\\changsha\\fog\\changsha_5.png', 'BeDDe\\changsha\\gt\\changsha_clear.png', '75_.png', '75_.png')

# %%
# Move pairs to respective folders
def move_pairs(pairs, output_hazy_folder, output_gt_folder):
    os.makedirs(output_hazy_folder, exist_ok=True)
    os.makedirs(output_gt_folder, exist_ok=True)
    for fog_path, gt_path, output_fog_name, output_gt_name in pairs:
        shutil.copy(fog_path, os.path.join(output_hazy_folder, output_fog_name))
        shutil.copy(gt_path, os.path.join(output_gt_folder, output_gt_name))

move_pairs(train_pairs, output_train_hazy, output_train_gt)
move_pairs(test_pairs, output_test_hazy, output_test_gt)
